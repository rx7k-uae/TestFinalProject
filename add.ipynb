# %% [markdown]
# <a href="https://colab.research.google.com/github/rx7k-uae/TestFinalProject/blob/main/add.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 12
b = 2
print (a+b)
# Out:
# 14
